# %% [markdown]
# # Day 1 : Python Problem Practice

# %%
readings = [0, 120, 850, -5, None, 1600, 400]

# %%
def sensor_data_classification(sensor_data):
    valid = []
    invalid = []
    suspicious = []
    missing = []
    sensor_data = sensor_data.item()
    if sensor_data < 0 :
        invalid.apend(sensor_data)
    elif sensor_data > 1100:
        suspicious.append(sensor_data)
    elif sensor_data == None:
        missing.append(sensor_data)
    else:
        valid.append(sensor_data)

    sensor_data_classifications = {
        'Valid': valid,
        'Invalid':invalid,
        'Suspicious': suspicious,
        'Missing': missing
    }
    return sensor_data_classifications

# %% [markdown]
# **The Correct Code**

# %%
def sensor_data_classification(sensor_data):
    valid = []
    invalid = []
    suspicious = []
    missing = []

    for data in sensor_data:
        if data == None :
            missing.append(data)
        else:
            if data > 1100:
                suspicious.append(data)
            elif data <0:
                invalid.append(data)
            else:
                valid.append(data)
                
                
            
    sensor_data_classifications = {
        'Valid': valid,
        'Invalid':invalid,
        'Suspicious': suspicious,
        'Missing': missing
    }
    return sensor_data_classifications

# %%
sensor_data_classification(readings)
# Out:
# {'Valid': [0, 120, 850, 400],
#  'Invalid': [-5],
#  'Suspicious': [1600],
#  'Missing': [None]}
